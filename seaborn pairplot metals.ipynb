# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
sns.set_context('notebook')
# %config InlineBackend.figure_format = 'retina'

# %%
data = pd.read_csv('metadataRWQ1.csv')

# %%
data.head()
# Out:
#    Solution Label  Sample ID Sample type Rack:Tube  Month    Type  \
# 0               1      32111         R11      1:01  March  Sample
# 1               2      32125         R25      1:02  March  Sample
# 2               3      32145         R56      1:03  March  Sample
# 3               4      42111         R11      1:04  April  Sample
# 4               5      42125         R25      1:05  April  Sample
#
#   Ag (328.068 nm) ppm   Ag Al (167.019 nm) ppm Al (396.152 nm) ppm  ...  \
# 0                                                                   ...
# 1                      NaN                                          ...
# 2                      NaN                                          ...
# 3                      NaN                                          ...
# 4                      NaN                                          ...
#
#   Se (ppm) Sr (407.771 nm) ppm  Sr (421.552 nm) ppm  Sr (ppm)  \
# 0                        1.083                1.050     2.133
# ...

# %%
data.columns
# Out:
# Index(['Solution Label', 'Sample ID', 'Sample type', 'Rack:Tube', 'Month',
#        'Type', 'Ag (328.068 nm) ppm', 'Ag', 'Al (167.019 nm) ppm',
#        'Al (396.152 nm) ppm', 'As (188.980 nm) ppm', 'As (193.696 nm) ppm',
#        'Ba (455.403 nm) ppm', 'Ba (ppm)', 'Ba (493.408 nm) ppm',
#        'Be (234.861 nm) ppm', 'Be (313.042 nm) ppm', 'Bi (222.821 nm) ppm',
#        'Bi (223.061 nm) ppm', 'Ca (183.944 nm) ppm', 'Ca (317.933 nm) ppm',
#        'Ca (ppm)', 'Cd (214.439 nm) ppm', 'Cd (226.502 nm) ppm',
#        'Co (228.615 nm) ppm', 'Co (238.892 nm) ppm', 'Cr (205.560 nm) ppm',
#        'Cr (267.716 nm) ppm', 'Cu (324.754 nm) ppm', 'Cu (327.395 nm) ppm',
#        'Cu (ppm)', 'Fe (234.350 nm) ppm', 'Fe (238.204 nm) ppm', 'Fe (ppm)',
#        'K (ppm)', 'Li (ppm)', 'Mg (ppm)', 'Mn (257.610 nm) ppm',
#        'Mn (259.372 nm) ppm', 'Mn (ppm)', 'Mo (202.032 nm) ppm',
#        'Mo (204.598 nm) ppm', 'Mo (ppm)', 'Na (ppm)', 'Ni (216.555 nm) ppm',
# ...

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
scatter_matrix(data[['Ba (ppm)','Ca (ppm)','Cu (ppm)','Fe (ppm)','K (ppm)','Li (ppm)','Mg (ppm)','Mo (ppm)','Na (ppm)','Ni (ppm)','P (ppm)','Se (ppm)','Sr (ppm)','V (ppm)']], figsize = (20, 20))
plt.show()

# %%
saleh=sns.pairplot(data,vars=['Ba (ppm)','Ca (ppm)','Cu (ppm)','K (ppm)','Li (ppm)','Mg (ppm)','Mo (ppm)','Na (ppm)','Sr (ppm)'], hue= 'Sample type')

# %%
sns.pairplot(data,vars=['Ba (ppm)','Ca (ppm)','Cu (ppm)','K (ppm)','Li (ppm)','Mg (ppm)','Mo (ppm)','Na (ppm)','Sr (ppm)'], kind="reg", hue= 'Sample type',corner=True, )

# %%
saleh

# %%
g = sns.PairGrid(data,vars=['Ba (ppm)','Ca (ppm)','Cu (ppm)','K (ppm)','Li (ppm)','Mg (ppm)','Mo (ppm)','Na (ppm)','Sr (ppm)'],diag_sharey=False, hue= 'Sample type')
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.scatterplot)
g.add_legend;

# %%
g = sns.PairGrid(data,
                 x_vars=['Mycobacterium CFU/100mL','DOC (mg/L)','UV254 (l/cm)','SUVA (L/mg-m)'], 
                 y_vars=['TDN (mg/L'],diag_sharey=False, hue= 'Location')
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.scatterplot);
